# %%
import numpy as np

# %%
x432 = np.load("/users/pmargani/tmp/AntennaPositions.432.npy")

# %%
x433 = np.load("/users/pmargani/tmp/AntennaPositions.433.npy")
y432 = np.load("/users/pmargani/tmp/CalibratedPower.432.npy")
y433 = np.load("/users/pmargani/tmp/CalibratedPower.433.npy")

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(16, 8))

# %%
plt.plot(x432, y432)

# %%
plt.plot(x433, y433)

# %%
plt.plot(y432)

# %%
plt.plot(y433
        )

# %%
yr432 = np.array(range(len(x432
                       )))

# %%
yr433= np.array(range(len(x433)))

# %%
plt.plot(x432, y432, x433, y433)

# %%
len(y432)
# Out:
# 229

# %%
len(y433)
# Out:
# 229

# %%
plt.plot(yr432, y432, yr433, y433)

# %%
l0432 = np.load("/users/pmargani/tmp/432-L-0.npy")
l1432 = np.load("/users/pmargani/tmp/432-L-1.npy")
l0433 = np.load("/users/pmargani/tmp/433-L-0.npy")
l1433 = np.load("/users/pmargani/tmp/433-L-1.npy")

# %%
plt.plot(yr432, l0432, yr432, l1432)

# %%
plt.plot(yr432, l0432, yr433, l0433)

# %%
plt.plot(yr432, l1432, yr433, l1433)

# %%
cL432 = np.load("/users/pmargani/tmp/cL432.npy")
cL433 = np.load("/users/pmargani/tmp/cL433.npy")

# %%
plt.plot(yr432, cL432, yr433, cL433)

# %%
y432org = np.load("/users/pmargani/tmp/CalibratedPower.432.org.npy")
y433org = np.load("/users/pmargani/tmp/CalibratedPower.433.org.npy")

# %%
plt.plot(yr432, y432, yr433, y433org)

# %%
x432org = np.load("/users/pmargani/tmp/AntennaPositions.432.org.npy")
x433org = np.load("/users/pmargani/tmp/AntennaPositions.433.org.npy")

# %%
plt.plot(yr432, y432org, yr433, y433org)

# %%
plt.plot(x432org, y432org, x433org, y433org)

# %%
y433.max()
# Out:
# 29.806649164624236

# %%
y433.max?

# %%
np.where(y433 == y433.max())
# Out:
# (array([123]),)

# %%
x433[123]
# Out:
# 0.25704183735538233

# %%
np.where(y432 == y432.max())
# Out:
# (array([106]),)

# %%
x432[106]
# Out:
# -0.21605833736211913
